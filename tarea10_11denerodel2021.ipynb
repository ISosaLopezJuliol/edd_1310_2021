# %% [markdown]
# <a href="https://colab.research.google.com/github/ISosaLopezJuliol/edd_1310_2021/blob/master/tarea10_11denerodel2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Queue:
    def __init__(self):
        self.__data = list()

    def is_empty (self):
        return len(self.__data)==0

    def length(self):
        return len(self.__data)

    def enqueue(self,elem):
        self.__data.append(elem)
    
    def dequeue (self):
        if not self.is_empty():
            return self.__data.pop(0) 
        else:
            return None
            
    def to_string (self):
        cadena = ""
        for elem in self.__data:
            cadena = cadena + "|" + str(elem)
        cadena = cadena +"|"
        return cadena




class BoundedPriorityQueue:
    def __init__(self , niveles):
        self.__data = [ Queue() for x in range(niveles) ]
        self.__size = 0

    def is_empty (self):
        return self.__size == 0

    def length(self):
        return self.__size

    def enqueue(self,prioridad,elem):
        if prioridad < len(self.__data) and prioridad >= 0:
            self.__data[prioridad].enqueue(elem)
            self.__size += 1

    def dequeue(self):
        if not self.is_empty():
            for nivel in self.__data:
                if not nivel.is_empty():
                    self.__size -= 1
                    return nivel.dequeue()

    def to_string (self):
        if not self.is_empty():
            for nivel in range (len(self.__data)):
                print(f"Nivel {nivel}-->{ self.__data[nivel].to_string()}")
            print("_____________________________________________")
        else: 
            print("------ No hay people en el barco ------")

# %%
q1 = Queue()
q1.enqueue(3)
q1.enqueue(33)
q1.enqueue(23)
print(q1.to_string())

print("Prueba 2 de Queue")
c1={'id': 1 ,  "nombre":"Mario" , "balance": 20.5 }
c2={'id': 2 ,  "nombre":"Maria" , "balance": 3456.5 }
c3={'id': 3 ,  "nombre":"Juan" , "balance": 1000000.0 }

atencion = Queue()
atencion.enqueue(c1)
atencion.enqueue(c2)
atencion.enqueue(c3)
print(atencion.to_string())
siguiente = atencion.dequeue()
print(f"Bienvenido sr.{siguiente['nombre']}, en que podemos servirle el dia de hoy")
print(atencion.to_string())


print("Prueba de las colas con priorida acotada")

maestres = {"prioridad" : 4 , "descripcion" : "maestre" , "personas" : ["juan p" , "diego h"] }
niños = {"prioridad" : 2 , "descripcion" : "niños" , "personas" : ["santi h" , "angel h"] }
mecanicos = {"prioridad" : 4 , "descripcion" : "mecanicos" , "personas" : ["diana t" , "maria z"] }
hombres = {"prioridad":3,"descripcion":"hombres","personas":["juan h" , "chava h"]}
vigia ={"prioridad":4,"descripcion":"vigias ","personas":["christian n" , "patricio e"]}
capitan = {"prioridad":5,"descripcion":"capitan","personas":["carlos c" , "ruth h"]}
timonel = {"prioridad":4,"descripcion":"timonel","personas":["jonathan c" , "braian m"]}
mujeres ={"prioridad":3,"descripcion":"mujeres ","personas":["noe l" , "joshua s"]}
ancianos = {"prioridad":2,"descripcion":"ancianos","personas":["maritza l" , "karen m"]}
niñas = {"prioridad":1,"descripcion":"niñas","personas":["lucia s" , "elizabeth a"]}

cpa = BoundedPriorityQueue(7)
cpa.enqueue(maestres['prioridad'],maestres)
cpa.enqueue(niños['prioridad'],niños)
cpa.enqueue(mecanicos['prioridad'],mecanicos)
cpa.enqueue(mujeres['prioridad'],mujeres)
cpa.enqueue(ancianos['prioridad'],ancianos)
cpa.enqueue(niñas['prioridad'],niñas)
cpa.enqueue(hombres['prioridad'],hombres)
cpa.enqueue(vigia['prioridad'],vigia)
cpa.enqueue(capitan['prioridad'],capitan)
cpa.enqueue(timonel['prioridad'],timonel)
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
cpa.dequeue()
cpa.to_string()
# Out:
# |3|33|23|
# Prueba 2 de Queue
# |{'id': 1, 'nombre': 'Mario', 'balance': 20.5}|{'id': 2, 'nombre': 'Maria', 'balance': 3456.5}|{'id': 3, 'nombre': 'Juan', 'balance': 1000000.0}|
# Bienvenido sr.Mario, en que podemos servirle el dia de hoy
# |{'id': 2, 'nombre': 'Maria', 'balance': 3456.5}|{'id': 3, 'nombre': 'Juan', 'balance': 1000000.0}|
# Prueba de las colas con priorida acotada
# Nivel 0-->|
# Nivel 1-->|{'prioridad': 1, 'descripcion': 'niñas', 'personas': ['lucia s', 'elizabeth a']}|
# Nivel 2-->|{'prioridad': 2, 'descripcion': 'niños', 'personas': ['santi h', 'angel h']}|{'prioridad': 2, 'descripcion': 'ancianos', 'personas': ['maritza l', 'karen m']}|
# Nivel 3-->|{'prioridad': 3, 'descripcion': 'mujeres ', 'personas': ['noe l', 'joshua s']}|{'prioridad': 3, 'descripcion': 'hombres', 'personas': ['juan h', 'chava h']}|
# ...
